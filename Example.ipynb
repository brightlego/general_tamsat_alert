# %%
from geographic_data import *
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
FILENAME = "drought-model-driving-data_pakistan_19820101-present_0.05.nc"
FIELD = "ndvi"

LON_LABEL = "lon"
LAT_LABEL = "lat"
TIME_LABEL = "time"

# %%
ds = xr.load_dataset(FILENAME)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 962, lat: 300, lon: 360)
# Coordinates:
#   * time     (time) datetime64[ns] 1982-01-15 1982-01-31 ... 2022-01-31
#   * lon      (lon) float64 60.02 60.07 60.12 60.17 ... 77.82 77.87 77.92 77.97
#   * lat      (lat) float64 37.98 37.93 37.88 37.83 ... 23.18 23.13 23.08 23.03
# Data variables:
#     ndvi     (time, lat, lon) float32 0.0 0.043 0.048 0.048 ... 0.33 0.333 0.307
#     vhi      (time, lat, lon) float32 0.0 28.82 46.83 ... 92.31 87.86 73.18
#     precip   (time, lat, lon) float32 7.953 8.028 8.044 ... 20.98 19.49 17.39
# Attributes:
#     regrid_method:  bilinear

# %%
period = get_periodicity(ds, FIELD, lon_label=LON_LABEL, lat_label=LAT_LABEL)
# Out:
# Finding Periodicity:	   1/1003 [                                ] 0.0% (37.93, 60.0   2/1003 [                                ] 0.1% (37.93, 60.5   3/1003 [                                ] 0.2% (37.93, 61.0   4/1003 [                                ] 0.3% (37.93, 61.5   5/1003 [                                ] 0.4% (37.93, 62.0   6/1003 [▏                               ] 0.5% (37.93, 62.5   7/1003 [▏                               ] 0.6% (37.93, 63.0   8/1003 [▏                               ] 0.7% (37.93, 63.5   9/1003 [▏                               ] 0.8% (37.93, 64.0  10/1003 [▎                               ] 0.9% (37.93, 64.5  11/1003 [▎                               ] 1.0% (37.93, 65.0  12/1003 [▎                               ] 1.1% (37.93, 65.5  13/1003 [▎                               ] 1.2% (37.93, 66.0  14/1003 [▍                               ] 1.3% (37.93, 66.5  15/1003 [▍                               ] 1.4% (37.93, 67.0  16/1003 [▍                               ] 1.
# ...
